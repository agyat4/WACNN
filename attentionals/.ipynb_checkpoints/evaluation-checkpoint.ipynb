# %% [markdown]
# ## Minimal Code to Evaluate A Neural Compression Model on SDO Image Data

# %% [markdown]
# #### 1. Importing required modules

# %%
import math

from PIL import Image
import matplotlib.pyplot as plt

import torch
from torchvision import transforms
from compressai.zoo import load_state_dict, models

from compressai.models import WACNN

# %%
# !pip install -e.
# Out:
# Obtaining file:///home/nlab/PycharmProjects/attentionals/attentionals
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (1.24.4)
# Requirement already satisfied: scipy in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (1.12.0)
# Requirement already satisfied: matplotlib in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (3.8.0)
# Requirement already satisfied: torch in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (2.1.2)
# Requirement already satisfied: torchvision in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (0.16.2)
# Requirement already satisfied: pytorch-msssim in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (1.0.0)
# Requirement already satisfied: timm in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (0.9.12)
# Requirement already satisfied: einops in /home/nlab/anaconda3/lib/python3.11/site-packages (from compressai==1.1.6.dev0) (0.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nlab/anaconda3/lib/python3.11/site-packages (from matplotlib->compressai==1.1.6.dev0) (2.8.2)
# Requirement already satisfied: pyyaml in /home/nlab/anaconda3/lib/python3.11/site-packages (from timm->compressai==1.1.6.dev0) (6.0.1)
# Requirement already satisfied: huggingface-hub in /home/nlab/anaconda3/lib/python3.11/site-packages (from timm->compressai==1.1.6.dev0) (0.20.2)
# Requirement already satisfied: safetensors in /home/nlab/anaconda3/lib/python3.11/site-packages (from timm->compressai==1.1.6.dev0) (0.3.3)
# Requirement already satisfied: filelock in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (4.9.0)
# Requirement already satisfied: sympy in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (1.12)
# Requirement already satisfied: networkx in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (3.2.1)
# Requirement already satisfied: jinja2 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (3.1.3)
# Requirement already satisfied: fsspec in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/nlab/anaconda3/lib/python3.11/site-packages (from torch->compressai==1.1.6.dev0) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/nlab/anaconda3/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->compressai==1.1.6.dev0) (12.3.101)
# Requirement already satisfied: requests in /home/nlab/anaconda3/lib/python3.11/site-packages (from torchvision->compressai==1.1.6.dev0) (2.31.0)
# Requirement already satisfied: six>=1.5 in /home/nlab/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->compressai==1.1.6.dev0) (1.16.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from huggingface-hub->timm->compressai==1.1.6.dev0) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nlab/anaconda3/lib/python3.11/site-packages (from jinja2->torch->compressai==1.1.6.dev0) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/nlab/anaconda3/lib/python3.11/site-packages (from requests->torchvision->compressai==1.1.6.dev0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nlab/anaconda3/lib/python3.11/site-packages (from requests->torchvision->compressai==1.1.6.dev0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nlab/anaconda3/lib/python3.11/site-packages (from requests->torchvision->compressai==1.1.6.dev0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nlab/anaconda3/lib/python3.11/site-packages (from requests->torchvision->compressai==1.1.6.dev0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /home/nlab/anaconda3/lib/python3.11/site-packages (from sympy->torch->compressai==1.1.6.dev0) (1.3.0)
# Installing collected packages: compressai
#   Attempting uninstall: compressai
#     Found existing installation: compressai 1.1.6.dev0
#     Uninstalling compressai-1.1.6.dev0:
#       Successfully uninstalled compressai-1.1.6.dev0
#   Running setup.py develop for compressai
# Successfully installed compressai-1.1.6.dev0

# %% [markdown]
# #### 2. Define saved checkpoint path/image path to be compressed, and the preferred device to use

# %%
checkpoint_path = '/home/nlab/PycharmProjects/attentionals/attentionals/ckpt_n/multispec4.path.tar'
image_path = '/home/nlab/data/multispectral_data/test_small/AIA20150902_1024.npy'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def rename_key(key: str) -> str:
    """Rename state_dict key."""

    # Deal with modules trained with DataParallel
    if key.startswith("module."):
        key = key[7:]

    # ResidualBlockWithStride: 'downsample' -> 'skip'
    # if ".downsample." in key:
    #     return key.replace("downsample", "skip")  # commented for nlpr

    # EntropyBottleneck: nn.ParameterList to nn.Parameters
    if key.startswith("entropy_bottleneck."):
        if key.startswith("entropy_bottleneck._biases."):
            return f"entropy_bottleneck._bias{key[-1]}"

        if key.startswith("entropy_bottleneck._matrices."):
            return f"entropy_bottleneck._matrix{key[-1]}"

        if key.startswith("entropy_bottleneck._factors."):
            return f"entropy_bottleneck._factor{key[-1]}"

    return key

# %% [markdown]
# #### 3. Load model with pretrained weights

# %%
state_dict = torch.load(checkpoint_path)['state_dict']
net = WACNN.from_state_dict(state_dict).eval().to(device)
# Out:
# /home/nlab/anaconda3/lib/python3.11/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
checkpoint = torch.load(checkpoint_path)
state_dict = load_state_dict(torch.load(checkpoint_path)['state_dict'])

# %% [markdown]
# #### 4. Read the candidate image and plot it for visualization

# %%
import numpy as np
img = np.load(image_path)
images=[]
for image in img:

    image[image < 1] = 1
    image = np.log2(image)
    image *= (255.0 / image.max())
    image = image.astype(np.uint8)
    # PIL_image=Image.fromarray(image.astype('uint8'))

    if image.ndim == 3 and image.shape[0] == 1:
        image = image.squeeze(0)

    image = np.array(image)

    images.append(image)
    # i+=1
# print("shape of images",len(images))
# print("the value of i ", i)
img = np.stack(images, axis=0)
imgT = np.transpose(img, (1, 2, 0))
print("img shape,",img.shape)
x = transforms.ToTensor()(imgT).unsqueeze(0).to(device)
'''
# %matplotlib inline
fig,axes = 
plt.figure(figsize=(12, 9))
plt.axis('off')
plt.imshow(img[i], cmap='gray')
plt.show()'''



num_images = len(img)
cols = num_images  # Number of columns equals the number of images

# Create a figure and axes
fig, axes = plt.subplots(1, cols, figsize=(24,16))

# Loop through each image and plot it
for i in range(num_images):
    axes[i].imshow(img[i], cmap="gray")
    axes[i].set_title(1)

    axes[i].axis("off")

plt.tight_layout()
plt.show()
# Out:
# img shape, (512, 512, 9)
# /tmp/ipykernel_47023/4245050155.py:48: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %% [markdown]
# #### 5. Feed the network and get the reconstruction + required bit-rate

# %%
with torch.no_grad():
    out_net = net.forward(x)
out_net['x_hat'].clamp_(0, 1)
print(out_net.keys())
# Out:
# dict_keys(['x_hat', 'likelihoods'])

# %%
def compute_psnr(a, b):
    mse = torch.mean((a - b)**2).item()
    return -10 * math.log10(mse)

def compute_bpp(out_net):
    size = out_net['x_hat'].size()
    num_pixels = size[0] * size[2] * size[3]
    return sum(torch.log(likelihoods).sum() / (-math.log(2) * num_pixels)
              for likelihoods in out_net['likelihoods'].values()).item()

# %% [markdown]
# #### 6. Report PSNR and Bit-rate

# %%
print(f'PSNR: {compute_psnr(x, out_net["x_hat"]):.2f}dB')
print(f'Bit-rate: {compute_bpp(out_net):.3f} bpp')
# Out:
# PSNR: 34.25dB
# Bit-rate: 0.164 bpp

# %% [markdown]
# #### 7. Visualize the reconstruction

# %%
rec_net = transforms.ToPILImage()(out_net['x_hat'].squeeze().cpu())

# %matplotlib inline
fix, axes = plt.subplots(1, 2, figsize=(16, 12))
for ax in axes:
    ax.axis('off')
    
axes[0].imshow(img, cmap='gray')
axes[0].title.set_text('Original')

axes[1].imshow(rec_net, cmap='gray')
axes[1].title.set_text('Reconstructed')


plt.show()
